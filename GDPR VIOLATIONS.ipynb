# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')

# %%
data=pd.read_table("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-04-21/gdpr_violations.tsv")
data.head(1)
# Out:
#    id                                            picture    name  price  \
# 0   1  https://www.privacyaffairs.com/wp-content/uplo...  Poland   9380
#
#                                            authority        date  \
# 0  Polish National Personal Data Protection Offic...  10/18/2019
#
#      controller article_violated  \
# 0  Polish Mayor     Art. 28 GDPR
#
#                                                 type  \
# 0  Non-compliance with lawful basis for data proc...
#
#                                         source  \
# 0  https://uodo.gov.pl/decyzje/ZSPU.421.3.2019
#
#                                              summary
# 0  No data processing agreement has been conclude...

# %% [markdown]
# ### 1. Time breakdown of the total violations in the EU.

# %%
data9=data.head(10)
date= data9.date
article_violated= data9.article_violated
type=data9.type
name=data9.name
plt.plot(date,article_violated)
plt.title('total violations in the EU')
plt.xlabel('date')
plt.ylabel('article_violated')
plt.show()

# %% [markdown]
# ### 2. Most expensive violation by country, listing the specific violation type e.g failure to comply with processing regulation.

# %%
data1=pd.DataFrame(data,columns=["name","price","type"])
most_expensive=data1.sort_values(by ="price",ascending=False).reset_index(drop=True)
most_expensive.head(1)
# Out:
#      name     price     type
# 0  France  50000000  Several

# %%
data3=most_expensive.head(10)
plt.xlabel("price")
plt.ylabel("country")
plt.title("Violations by country")
plt.legend("type")
plt.hist(data3)
# Out:
# (array([[10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [ 3.,  3.,  1.,  1.,  0.,  1.,  0.,  0.,  0.,  1.],
#         [10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.0, 5000000.0, 10000000.0, 15000000.0, 20000000.0, 25000000.0,
#         30000000.0, 35000000.0, 40000000.0, 45000000.0, 50000000.0],
#        dtype=object),
#  <a list of 3 BarContainer objects>)

# %% [markdown]
# ### 3. Vodafone's GDPR violations in volume.

# %% [markdown]
# ### 4. Companies with the highest violations

# %%
data7=pd.DataFrame(data,columns=["price","controller"])
highest_violations=data7.sort_values(by ="price",ascending=False).reset_index(drop=True)
highest_violations.head(6)
# Out:
#       price              controller
# 0  50000000             Google Inc.
# 1  27802946  TIM - Telecom Provider
# 2  18000000           Austrian Post
# 3  14500000      Deutsche Wohnen SE
# 4   9550000        1&1 Telecom GmbH
# 5   8500000          Eni Gas e Luce

# %% [markdown]
# ### 5. Map the data and make this interactive. Bonus but useful.

# %% [markdown]
# ### 6. Breakdown / Distribution and important metrics of fines levied per article. Prepare a Box, plot.

# %%
import seaborn as sns
sns.set()
with sns.axes_style(style='ticks'):
    g = sns.factorplot("article_violated", "price", data= data, kind="box")
    g.set_axis_labels("article_violated", "price");
# Out:
# C:\Users\LUCY ADHIS\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\LUCY ADHIS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\LUCY ADHIS\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\LUCY ADHIS\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 7. Top 10 most violated articles

# %%
data3=pd.DataFrame(data,columns=["article_violated","price"])
top_ten=data3.sort_values(by = "price",ascending=False).reset_index(drop=True)
top_ten.head(10)
# Out:
#                                     article_violated     price
# 0  Art. 13 GDPR|Art. 14 GDPR|Art. 6 GDPR|Art. 4 G...  50000000
# 1                                    Art. 58(2) GDPR  27802946
# 2                     Art. 5 (1) a) GDPR|Art. 6 GDPR  18000000
# 3                           Art. 5 GDPR|Art. 25 GDPR  14500000
# 4                                       Art. 32 GDPR   9550000
# 5  Art. 5 GDPR|Art. 6 GDPR|Art. 17 GDPR|Art. 21 GDPR   8500000
# 6               Art. 5 GDPR|Art. 6 GDPR|Art. 17 GDPR   7000000
# 7                            Art. 5 GDPR|Art. 6 GDPR   3000000
# 8                                       Art. 32 GDPR   2600000
# 9                                       Art. 32 GDPR    900000

# %% [markdown]
# ### 8. Article with the highest associated fine

# %%
data5=pd.DataFrame(data, columns=("article_violated","price"))
highest_fine=data5.sort_values(by = "price",ascending=True).reset_index(drop=True)
highest_fine.head(5)
# Out:
#            article_violated  price
# 0              Art. 32 GDPR      0
# 1  Art. 5 GDPR|Art. 25 GDPR      0
# 2               Art. 6 GDPR      0
# 3     Art. 15 (1), (3) GDPR      0
# 4              Art. 32 GDPR      0

# %%
#Article 32 has the highest associated fine
